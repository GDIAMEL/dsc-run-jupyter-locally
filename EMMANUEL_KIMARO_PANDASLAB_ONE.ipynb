# %% [markdown]
# <a href="https://colab.research.google.com/github/GDIAMEL/dsc-run-jupyter-locally/blob/main/EMMANUEL_KIMARO_PANDASLAB_ONE.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Accessing Data within Pandas - Lab

# %% [markdown]
# ## Introduction
#
# In this lab, we'll look at a dataset which contains information on World Cup matches. Let's use the pandas commands learned in the previous lesson to learn more about our data!

# %% [markdown]
# ## Objectives
#
# You will be able to:
#
# - Use pandas methods and attributes to access information about a dataset
# - Index pandas dataframes with .loc, .iloc, and column names
# - Use a boolean mask to index pandas series and dataframes

# %% [markdown]
# ## Load the Data

# %% [markdown]
# Load the file `'WorldCupMatches.csv'` as a DataFrame in pandas.

# %%
# Replace None with appropriate code

# Import pandas using the standard alias
import pandas as pd

# Load 'WorldCupMatches.csv' as a DataFrame
df = pd.read_csv('WorldCupMatches.csv')

# %% [markdown]
# ## Common Methods and Attributes

# %% [markdown]
# Use the correct method to display the **first 7 rows** of the dataset.

# %%
#first 7 rows of the data set
df.head(7)
# Out:
#    Year              Datetime    Stage         Stadium         City  \
# 0  1930  13 Jul 1930 - 15:00   Group 1         Pocitos  Montevideo
# 1  1930  13 Jul 1930 - 15:00   Group 4  Parque Central  Montevideo
# 2  1930  14 Jul 1930 - 12:45   Group 2  Parque Central  Montevideo
# 3  1930  14 Jul 1930 - 14:50   Group 3         Pocitos  Montevideo
# 4  1930  15 Jul 1930 - 16:00   Group 1  Parque Central  Montevideo
# 5  1930  16 Jul 1930 - 14:45   Group 1  Parque Central  Montevideo
# 6  1930  17 Jul 1930 - 12:45   Group 2  Parque Central  Montevideo
#
#   Home Team Name  Home Team Goals  Away Team Goals Away Team Name  \
# 0         France                4                1         Mexico
# 1            USA                3                0        Belgium
# 2     Yugoslavia                2                1         Brazil
# 3        Romania                3                1           Peru
# 4      Argentina                1                0         France
# 5          Chile                3                0         Mexico
# 6     Yugoslavia                4                0        Bolivia
#
#   Win conditions  Attendance  Half-time Home Goals  Half-time Away Goals  \
# 0                     4444.0                     3                     0
# 1                    18346.0                     2                     0
# 2                    24059.0                     2                     0
# 3                     2549.0                     1                     0
# 4                    23409.0                     0                     0
# 5                     9249.0                     1                     0
# 6                    18306.0                     0                     0
#
#                     Referee               Assistant 1  \
# 0    LOMBARDI Domingo (URU)     CRISTOPHE Henry (BEL)
# 1         MACIAS Jose (ARG)  MATEUCCI Francisco (URU)
# 2       TEJADA Anibal (URU)   VALLARINO Ricardo (URU)
# 3     WARNKEN Alberto (CHI)       LANGENUS Jean (BEL)
# 4       REGO Gilberto (BRA)      SAUCEDO Ulises (BOL)
# 5     CRISTOPHE Henry (BEL)   APHESTEGUY Martin (URU)
# 6  MATEUCCI Francisco (URU)    LOMBARDI Domingo (URU)
#
#                   Assistant 2  RoundID  MatchID Home Team Initials  \
# 0         REGO Gilberto (BRA)      201     1096                FRA
# 1       WARNKEN Alberto (CHI)      201     1090                USA
# 2         BALWAY Thomas (FRA)      201     1093                YUG
# 3    MATEUCCI Francisco (URU)      201     1098                ROU
# 4  RADULESCU Constantin (ROU)      201     1085                ARG
# 5         LANGENUS Jean (BEL)      201     1095                CHI
# 6       WARNKEN Alberto (CHI)      201     1092                YUG
#
#   Away Team Initials
# 0                MEX
# 1                BEL
# 2                BRA
# 3                PER
# 4                FRA
# 5                MEX
# 6                BOL

# %% [markdown]
# Display the **last 3 rows** of the dataset.

# %%
# a display of the last 3 rows of the dataset
df.tail(3)
# Out:
#      Year              Datetime                     Stage  \
# 849  2014  09 Jul 2014 - 17:00                Semi-finals
# 850  2014  12 Jul 2014 - 17:00   Play-off for third place
# 851  2014  13 Jul 2014 - 16:00                      Final
#
#                  Stadium             City Home Team Name  Home Team Goals  \
# 849   Arena de Sao Paulo       Sao Paulo     Netherlands                0
# 850     Estadio Nacional        Brasilia          Brazil                0
# 851  Estadio do Maracana  Rio De Janeiro         Germany                1
#
#      Away Team Goals Away Team Name                       Win conditions  \
# 849                0      Argentina  Argentina win on penalties (2 - 4)
# 850                3    Netherlands
# 851                0      Argentina        Germany win after extra time
#
#      Attendance  Half-time Home Goals  Half-time Away Goals  \
# 849     63267.0                     0                     0
# 850     68034.0                     0                     2
# 851     74738.0                     0                     0
#
#                    Referee            Assistant 1              Assistant 2  \
# 849     C�neyt �AKIR (TUR)   DURAN Bahattin (TUR)        ONGUN Tarik (TUR)
# 850  HAIMOUDI Djamel (ALG)   ACHIK Redouane (MAR)  ETCHIALI Abdelhak (ALG)
# 851   Nicola RIZZOLI (ITA)  Renato FAVERANI (ITA)     Andrea STEFANI (ITA)
#
#      RoundID    MatchID Home Team Initials Away Team Initials
# 849   255955  300186490                NED                ARG
# 850   255957  300186502                BRA                NED
# 851   255959  300186501                GER                ARG

# %% [markdown]
# Get a concise summary of the data using `.info()`.

# %%
# a summary of the worldcupmatch data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 852 entries, 0 to 851
# Data columns (total 20 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Year                  852 non-null    int64
#  1   Datetime              852 non-null    object
#  2   Stage                 852 non-null    object
#  3   Stadium               852 non-null    object
#  4   City                  852 non-null    object
#  5   Home Team Name        852 non-null    object
#  6   Home Team Goals       852 non-null    int64
#  7   Away Team Goals       852 non-null    int64
#  8   Away Team Name        852 non-null    object
#  9   Win conditions        852 non-null    object
#  10  Attendance            850 non-null    float64
#  11  Half-time Home Goals  852 non-null    int64
#  12  Half-time Away Goals  852 non-null    int64
#  13  Referee               852 non-null    object
#  14  Assistant 1           852 non-null    object
#  15  Assistant 2           852 non-null    object
#  16  RoundID               852 non-null    int64
#  17  MatchID               852 non-null    int64
#  18  Home Team Initials    852 non-null    object
#  19  Away Team Initials    852 non-null    object
# dtypes: float64(1), int64(7), object(12)
# memory usage: 133.2+ KB

# %% [markdown]
# Obtain a tuple representing the **number of rows and number of columns**.

# %%
# A representation of the number of rows and columns
df.shape
# Out:
# (852, 20)

# %% [markdown]
# Use the appropriate attribute to get the **column names**.

# %%
# information of the columns
df.columns
# Out:
# Index(['Year', 'Datetime', 'Stage', 'Stadium', 'City', 'Home Team Name',
#        'Home Team Goals', 'Away Team Goals', 'Away Team Name',
#        'Win conditions', 'Attendance', 'Half-time Home Goals',
#        'Half-time Away Goals', 'Referee', 'Assistant 1', 'Assistant 2',
#        'RoundID', 'MatchID', 'Home Team Initials', 'Away Team Initials'],
#       dtype='object')

# %% [markdown]
# ## Selecting DataFrame Information

# %% [markdown]
# When looking at the DataFrame's `.head()` and `.tail()`, you might have noticed that the games are structured chronologically in the DataFrame.
#
# Use the right selection method to display all the information from the 3rd to the 5th game (i.e. **select rows 3 through 5 inclusive**).

# %%
# all the information about the third to the fifth game
df[3:6]
# Out:
#    Year              Datetime    Stage         Stadium         City  \
# 3  1930  14 Jul 1930 - 14:50   Group 3         Pocitos  Montevideo
# 4  1930  15 Jul 1930 - 16:00   Group 1  Parque Central  Montevideo
# 5  1930  16 Jul 1930 - 14:45   Group 1  Parque Central  Montevideo
#
#   Home Team Name  Home Team Goals  Away Team Goals Away Team Name  \
# 3        Romania                3                1           Peru
# 4      Argentina                1                0         France
# 5          Chile                3                0         Mexico
#
#   Win conditions  Attendance  Half-time Home Goals  Half-time Away Goals  \
# 3                     2549.0                     1                     0
# 4                    23409.0                     0                     0
# 5                     9249.0                     1                     0
#
#                  Referee              Assistant 1                 Assistant 2  \
# 3  WARNKEN Alberto (CHI)      LANGENUS Jean (BEL)    MATEUCCI Francisco (URU)
# 4    REGO Gilberto (BRA)     SAUCEDO Ulises (BOL)  RADULESCU Constantin (ROU)
# 5  CRISTOPHE Henry (BEL)  APHESTEGUY Martin (URU)         LANGENUS Jean (BEL)
#
#    RoundID  MatchID Home Team Initials Away Team Initials
# 3      201     1098                ROU                PER
# 4      201     1085                ARG                FRA
# 5      201     1095                CHI                MEX

# %% [markdown]
# Now, display the info from **game 5-9** (inclusive), but **only the `"Home Team Name"` and the `"Away Team Name"` columns**.

# %%
# game information for both the home and away team
df[5:10][['Home Team Name','Away Team Name']]
# Out:
#   Home Team Name Away Team Name
# 5          Chile         Mexico
# 6     Yugoslavia        Bolivia
# 7            USA       Paraguay
# 8        Uruguay           Peru
# 9          Chile         France

# %% [markdown]
# Next, we'd like the information on all the games played in **Group 3** for the **1950** World Cup.

# %% [markdown]
# Hint: You can combine conditions like this:
#
# `df[(condition1) | (condition2)]`  -> Returns rows where either condition is true
#
# `df[(condition1) & (condition2)]`  -> Returns rows where both conditions are true

# %%
# here the code will contain information of all games played in the world cup 1950 for group 3
df[(df["Year"] == 1950) & (df["Stage"] == "Group 3")]
# Out:
#     Year              Datetime    Stage           Stadium        City  \
# 56  1950  25 Jun 1950 - 15:00   Group 3          Pacaembu  Sao Paulo
# 61  1950  29 Jun 1950 - 15:30   Group 3  Durival de Brito   Curitiba
# 65  1950  02 Jul 1950 - 15:00   Group 3          Pacaembu  Sao Paulo
#
#    Home Team Name  Home Team Goals  Away Team Goals Away Team Name  \
# 56         Sweden                3                2          Italy
# 61         Sweden                2                2       Paraguay
# 65          Italy                2                0       Paraguay
#
#    Win conditions  Attendance  Half-time Home Goals  Half-time Away Goals  \
# 56                    36502.0                     2                     1
# 61                     7903.0                     2                     1
# 65                    25811.0                     1                     0
#
#                   Referee             Assistant 1                Assistant 2  \
# 56        LUTZ Jean (SUI)     BERANEK Alois (AUT)        TEJADA Carlos (MEX)
# 61  MITCHELL Robert (SCO)       LEMESIC Leo (YUG)     GARCIA Prudencio (USA)
# 65     ELLIS Arthur (ENG)  GARCIA Prudencio (USA)  DE LA SALLE Charles (FRA)
#
#     RoundID  MatchID Home Team Initials Away Team Initials
# 56      208     1219                SWE                ITA
# 61      208     1228                SWE                PAR
# 65      208     1218                ITA                PAR

# %% [markdown]
# Let's repeat the command above, but this time display **only the attendance column** for the Group 3 games.

# %%
# focusing only on the attendance column below is the code
df[(df["Year"] == 1950) & (df["Stage"] == "Group 3")][['Attendance']]
# Out:
#     Attendance
# 56     36502.0
# 61      7903.0
# 65     25811.0

# %% [markdown]
# Throughout the entire history of the World Cup as recorded in this dataset, **how many home games were played by the Netherlands**?
#
# (Remember that you can use the `len()` built-in function to find the number of rows in a DataFrame.)

# %%
# for len function i have used it to find the number of rows
len(df[(df["Home Team Name"] == "Netherlands") & (df["Stage"] == "Final")])
# Out:
# 2

# %%
# below is the code that shows the total number of games played by netherlands for home
df.loc[df['Home Team Name'] == 'Netherlands', 'Home Team Name'].count()
# Out:
# 32

# %% [markdown]
# **How many games were played by the Netherlands in total**?

# %%
# i will code for both home and away games for netherlands to find the total games below
df.loc[df['Home Team Name'] == 'Netherlands', 'Home Team Name'].count() + df.loc[df['Away Team Name'] == 'Netherlands', 'Away Team Name'].count()
# Out:
# 54

# %% [markdown]
# Next, let's try and figure
# 376                1                0           Algeria
# 377                0                0           Morocco
# 378                1                2             Spain
# 379                1                1          Paraguay
# 380                1                0          Portugal
# 381                1                2           Belgium
# 382                6                1           Uruguay
# 383                2                1          Scotland
# 384                0                3            France
# 385                2                0            Canada
# 386                2                3             Italy
# 387                2                0          Bulgaria
# 388                2                2           Belgium
# 389                0                1            Mexico
# 390                1                3           Morocco
# 391                3                0            Poland
# 392                0                3            Brazil
# 393                0                3             Spain
# 394                0                0           Uruguay
# 395                2                0        Germany FR
# 396                3                4           Belgium
# 397                2                0          Bulgaria
# 398                1                0           Uruguay
# 399                4                0            Poland
# 400                0                2            France
# 401                0                1        Germany FR
# 402                3                0          Paraguay
# 403                1                5             Spain
# 404                1                1            France
# 405                0                0            Mexico
# 406                1                1           Belgium
# 407                2                1           England
# 408                0                2        Germany FR
# 409                2                0           Belgium
# 410                4                2           Belgium
# 411                3                2        Germany FR
#
#                            Win conditions  ...  Half-time Away Goals  \
# 360                                        ...                     1
# 361                                        ...                     0
# 362                                        ...                     0
# 363                                        ...                     0
# 364                                        ...                     0
# 365                                        ...                     0
# 366                                        ...                     1
# 367                                        ...                     2
# 368                                        ...                     0
# 369                                        ...                     0
# 370                                        ...                     0
# 371                                        ...                     0
# 372                                        ...                     1
# 373                                        ...                     0
# 374                                        ...                     1
# 375                                        ...                     0
# 376                                        ...                     0
# 377                                        ...                     0
# 378                                        ...                     2
# 379                                        ...                     0
# 380                                        ...                     0
# 381                                        ...                     2
# 382                                        ...                     1
# 383                                        ...                     1
# 384                                        ...                     1
# 385                                        ...                     0
# 386                                        ...                     1
# 387                                        ...                     0
# 388                                        ...                     1
# 389                                        ...                     0
# 390                                        ...                     2
# 391                                        ...                     0
# 392                                        ...                     2
# 393                                        ...                     1
# 394                                        ...                     0
# 395                                        ...                     0
# 396         Belgium win after extra time   ...                     0
# 397                                        ...                     0
# 398                                        ...                     0
# 399                                        ...                     0
# 400                                        ...                     1
# 401                                        ...                     0
# 402                                        ...                     0
# 403                                        ...                     1
# 404      France win on penalties (3 - 4)   ...                     0
# 405  Germany FR win on penalties (4 - 1)   ...                     0
# 406     Belgium win on penalties (4 - 5)   ...                     0
# 407                                        ...                     0
# 408                                        ...                     1
# 409                                        ...                     0
# 410          France win after extra time   ...                     0
# 411                                        ...                     0
#
#                                 Referee                         Assistant 1  \
# 360              FREDRIKSSON Erik (SWE)        CODESAL MENDEZ Edgardo (MEX)
# 361             SILVA ARCE Hernan (CHI)          MENDEZ MOLINA Romulo (GUA)
# 362         BAMBRIDGE Christopher (AUS)                   SOCHA David (USA)
# 363                 AGNOLIN Luigi (ITA)               COURTNEY George (ENG)
# 364    SANCHEZ ARMINIO Victoriano (ESP)          GONZALEZ ROA Gabriel (PAR)
# 365      MARTINEZ BAZAN Jose Luis (URU)                  QUINIOU Joel (FRA)
# 366                BUTENKO Valeri (RUS)                   DAINA Andre (SUI)
# 367               ESPOSITO Carlos (ARG)  SILVA VALENTE Carlos Alberto (POR)
# 368                   ROTH Volker (GER)                DOTCHEV Bogdan (BUL)
# 369            PICON-ACKONG Edwin (MRI)            ULLOA MORERA Berny (CRC)
# 370                  NEMETH Lajos (HUN)            KIRSCHEN Siegfried (GER)
# 411          ARPPI FILHO Romualdo (BRA)              FREDRIKSSON Erik (SWE)
#
#                             Assistant 2 RoundID MatchID  Home Team Initials  \
# 360                   ROTH Volker (GER)     308     459                 BUL
# 361            ULLOA MORERA Berny (CRC)     308     468                 CAN
# 362                    KEIZER Jan (NED)     308     439                 ESP
# 363               BRUMMEIER Horst (AUT)     308     610                 URS
# 364            DIAZ PALACIO Jesus (COL)     308     395                 ARG
# 365                TRAORE Idrissa (MLI)     308     674                 MAR
# 366                PETROVIC Zoran (SRB)     308     379                 ALG
# 367          MENDEZ MOLINA Romulo (GUA)     308     428                 BEL
# 368               AL SHARIF Jamal (SYR)     308     538                 POR
# 369                   SOCHA David (USA)     308     628                 PAR
# 370       AL SHANAR Fallaj Khuzam (KSA)     308     517                 SCO
# 371  SILVA VALENTE Carlos Alberto (POR)     308     585                 URU
# 372                   SNODDY Alan (NIR)     308     394                 ITA
# 373                 TAKADA Shizuo (JPN)     308     571                 FRA
# 374                BUTENKO Valeri (RUS)     308     460                 NSK
# 375         BAMBRIDGE Christopher (AUS)     308     475                 HUN
# 376                  QUINIOU Joel (FRA)     308     377                 BRA
# 377            KIRSCHEN Siegfried (GER)     308     533                 ENG
# 378                  NEMETH Lajos (HUN)     308     551                 NIR
# 379                     IGNA Ioan (ROU)     308     680                 MEX
# 380                 TAKADA Shizuo (JPN)     308     701                 POL
# 381    SANCHEZ ARMINIO Victoriano (ESP)     308     427                 IRQ
# 382          ARPPI FILHO Romualdo (BRA)     308     522                 DEN
# 383                   SNODDY Alan (NIR)     308     580                 FRG
# 384                   DAINA Andre (SUI)     308     567                 HUN
# 385          GONZALEZ ROA Gabriel (PAR)     308     476                 URS
# 386               AL SHARIF Jamal (SYR)     308     643                 NSK
# 387      MARTINEZ BAZAN Jose Luis (URU)     308     389                 ARG
# 388             SILVA ARCE Hernan (CHI)     308     429                 PAR
# 389                 AGNOLIN Luigi (ITA)     308     627                 IRQ
# 390                   ROTH Volker (GER)     308     675                 POR
# 391              CHRISTOV Vojtech (TCH)     308     537                 ENG
# 392               COURTNEY George (ENG)     308     441                 NIR
# 393               ESPOSITO Carlos (ARG)     308     378                 ALG
# 394                 BENNACEUR Ali (TUN)     308     712                 SCO
# 395              FREDRIKSSON Erik (SWE)     308     512                 DEN
# 396                   SOCHA David (USA)     309     432                 URS
# 397                     IGNA Ioan (ROU)     309     463                 MEX
# 398  SILVA VALENTE Carlos Alberto (POR)     309     398                 ARG
# 399                   SNODDY Alan (NIR)     309     444                 BRA
# 400            DIAZ PALACIO Jesus (COL)     309     568                 ITA
# 401               BRUMMEIER Horst (AUT)     309     574                 MAR
# 402       AL SHANAR Fallaj Khuzam (KSA)     309     536                 ENG
# 403                DOTCHEV Bogdan (BUL)     309     511                 DEN
# 404              CHRISTOV Vojtech (TCH)     714     440                 BRA
# 405                   SNODDY Alan (NIR)     714     575                 FRG
# 406               BRUMMEIER Horst (AUT)     714     421                 ESP
# 407                DOTCHEV Bogdan (BUL)     714     392                 ARG
# 408                  NEMETH Lajos (HUN)    3469     564                 FRA
# 409  SILVA VALENTE Carlos Alberto (POR)    3469     388                 ARG
# 410               AL SHARIF Jamal (SYR)    3468     422                 FRA
# 411            ULLOA MORERA Berny (CRC)    3467     393                 ARG
#
#      Away Team Initials Total Goals Half-time Goals
# 360                 ITA           2               1
# 361                 FRA           1               0
# 362                 BRA           1               0
# 363                 HUN           6               3
# 364                 KOR           4               2
# 365                 POL           0               0
# 366                 NIR           2               1
# 367                 MEX           3               3
# 368                 ENG           1               0
# 369                 IRQ           1               1
# 370                 DEN           1               0
# 371                 FRG           2               1
# 372                 ARG           2               2
# 373                 URS           2               0
# 374                 BUL           2               1
# 375                 CAN           2               1
# 376                 ALG           1               0
# 377                 MAR           0               0
# 378                 ESP           3               2
# 379                 PAR           2               1
# 380                 POR           1               0
# 381                 BEL           3               2
# 382                 URU           7               3
# 383                 SCO           3               2
# 384                 FRA           3               1
# 385                 CAN           2               0
# 386                 ITA           5               1
# 387                 BUL           2               1
# 388                 BEL           4               1
# 389                 MEX           1               0
# 390                 MAR           4               2
# 391                 POL           3               3
# 392                 BRA           3               2
# 393                 ESP           3               1
# 394                 URU           0               0
# 395                 FRG           2               1
# 396                 BEL           7               0
# 397                 BUL           2               1
# 398                 URU           1               1
# 399                 POL           4               1
# 400                 FRA           2               1
# 401                 FRG           1               0
# 402                 PAR           3               1
# 403                 ESP           6               2
# 404                 FRA           2               0
# 405                 MEX           0               0
# 406                 BEL           2               0
# 407                 ENG           3               0
# 408                 FRG           2               1
# 409                 BEL           2               0
# 410                 BEL           6               0
# 411                 FRG           5               1
#
# [52 rows x 22 columns]

# %% [markdown]
# ## Changing Values and Creating New Columns

# %% [markdown]
# In World Cup history, **how many matches had 5 goals or more in total**? Create a column `"Total Goals"` to answer this question.

# %%
# first, i will code for the total number of goals to be displayed
# then, i will code for the matches that had five goals or more in total
df['Total Goals'] = df['Home Team Goals'] + df['Away Team Goals']
df.loc[df['Total Goals'] >= 5]
# Out:
#      Year              Datetime        Stage             Stadium  \
# 0    1930  13 Jul 1930 - 15:00       Group 1             Pocitos
# 10   1930  19 Jul 1930 - 15:00       Group 1  Estadio Centenario
# 15   1930  26 Jul 1930 - 14:45   Semi-finals  Estadio Centenario
# 16   1930  27 Jul 1930 - 14:45   Semi-finals  Estadio Centenario
# 17   1930  30 Jul 1930 - 14:15         Final  Estadio Centenario
# ..    ...                   ...          ...                 ...
# 806  2014  23 Jun 2014 - 17:00       Group A    Estadio Nacional
# 810  2014  24 Jun 2014 - 16:00       Group C      Arena Pantanal
# 812  2014  25 Jun 2014 - 13:00       Group F   Estadio Beira-Rio
# 826  2014  08 Jul 2014 - 17:00   Semi-finals    Estadio Mineirao
# 848  2014  08 Jul 2014 - 17:00   Semi-finals    Estadio Mineirao
#
#                 City Home Team Name  Home Team Goals  Away Team Goals  \
# 0        Montevideo          France                4                1
# 10       Montevideo       Argentina                6                3
# 15       Montevideo       Argentina                6                1
# 16       Montevideo         Uruguay                6                1
# 17       Montevideo         Uruguay                4                2
# ..               ...            ...              ...              ...
# 806        Brasilia        Cameroon                1                4
# 810          Cuiaba           Japan                1                4
# 812    Porto Alegre         Nigeria                2                3
# 826  Belo Horizonte          Brazil                1                7
# 848  Belo Horizonte          Brazil                1                7
#
#     Away Team Name Win conditions  ...  Half-time Away Goals  \
# 0           Mexico                 ...                     0
# 10          Mexico                 ...                     1
# 15             USA                 ...                     0
# 16      Yugoslavia                 ...                     1
# 17       Argentina                 ...                     2
# ..             ...            ...  ...                   ...
# 806         Brazil                 ...                     2
# 810       Colombia                 ...                     1
# 812      Argentina                 ...                     2
# 826        Germany                 ...                     5
# 848        Germany                 ...                     5
#
#                     Referee              Assistant 1  \
# 0    LOMBARDI Domingo (URU)    CRISTOPHE Henry (BEL)
# 10     SAUCEDO Ulises (BOL)   ALONSO Gualberto (URU)
# 15      LANGENUS Jean (BEL)     VALLEJO Gaspar (MEX)
# 16      REGO Gilberto (BRA)     SAUCEDO Ulises (BOL)
# 17      LANGENUS Jean (BEL)     SAUCEDO Ulises (BOL)
# ..                      ...                      ...
# 806    ERIKSSON Jonas (SWE)  KLASENIUS Mathias (SWE)
# 810     PROENCA Pedro (POR)    MIRANDA Bertino (POR)
# 812    Nicola RIZZOLI (ITA)    Renato FAVERANI (ITA)
# 826   RODRIGUEZ Marco (MEX)  TORRENTERA Marvin (MEX)
# 848   RODRIGUEZ Marco (MEX)  TORRENTERA Marvin (MEX)
#
#                     Assistant 2 RoundID    MatchID  Home Team Initials  \
# 0           REGO Gilberto (BRA)     201       1096                 FRA
# 10   RADULESCU Constantin (ROU)     201       1086                 ARG
# 15        WARNKEN Alberto (CHI)     202       1088                 ARG
# 16          BALWAY Thomas (FRA)     202       1101                 URU
# 17        CRISTOPHE Henry (BEL)     405       1087                 URU
# ..                          ...     ...        ...                 ...
# 806       WARNMARK Daniel (SWE)  255931  300186472                 CMR
# 810            TRIGO Jose (POR)  255931  300186457                 JPN
# 812        Andrea STEFANI (ITA)  255931  300186458                 NGA
# 826       QUINTERO Marcos (MEX)  255955  300186474                 BRA
# 848       QUINTERO Marcos (MEX)  255955  300186474                 BRA
#
#      Away Team Initials Total Goals Half-time Goals
# 0                   MEX           5               3
# 10                  MEX           9               4
# 15                  USA           7               1
# 16                  YUG           7               4
# 17                  ARG           6               3
# ..                  ...         ...             ...
# 806                 BRA           5               3
# 810                 COL           5               2
# 812                 ARG           5               3
# 826                 GER           8               5
# 848                 GER           8               5
#
# [147 rows x 22 columns]

# %% [markdown]
# Now **create a new column `"Half-time Goals"`** in `df` that includes both home and away values.

# %%
# creating a column for the total half time goals for the world cup
df['Half-time Goals'] = df['Half-time Home Goals'] + df['Half-time Away Goals']

# %%
# Run this cell without changes to see your new column
df.columns
# Out:
# Index(['Year', 'Datetime', 'Stage', 'Stadium', 'City', 'Home Team Name',
#        'Home Team Goals', 'Away Team Goals', 'Away Team Name',
#        'Win conditions', 'Attendance', 'Half-time Home Goals',
#        'Half-time Away Goals', 'Referee', 'Assistant 1', 'Assistant 2',
#        'RoundID', 'MatchID', 'Home Team Initials', 'Away Team Initials',
#        'Total Goals', 'Half-time Goals'],
#       dtype='object')

# %% [markdown]
# Run the code below. You'll notice that for Korea, there are records for both North-Korea (Korea DPR) and South-Korea (Korea Republic).

# %%
# Run this cell without changes

# Display all records containing the string 'Korea'
df.loc[df['Home Team Name'].str.contains('Korea'), 'Home Team Name']
# Out:
# 179    Korea
# 187    Korea
# 374    Korea
# 386    Korea
# 434    Korea
# 444    Korea
# 480    Korea
# 524    Korea
# 593    Korea
# 609    Korea
# 635    Korea
# 642    Korea
# 655    Korea
# 710    Korea
# 753    Korea
# 802    Korea
# 818    Korea
# Name: Home Team Name, dtype: object

# %% [markdown]
# Imagine that, for some reason, we simply want Korea listed as one entry, so we want to replace every "Home Team Name" and "Away Team Name" entry that contains "Korea" to simply "Korea". In the same way, we want to change the columns "Home Team Initials" and "Away Team Initials" to NSK (North & South Korea) instead of "KOR" and "PRK".

# %%
# Update the 'Home Team Name' and 'Home Team Initials' columns
df.loc[df['Home Team Initials'].str.contains('KOR'), 'Home Team Initials'] = 'NSK'

# %% [markdown]
# Make sure to verify your answer!

# %%
# Check the updated columns
df.columns
# Out:
# Index(['Year', 'Datetime', 'Stage', 'Stadium', 'City', 'Home Team Name',
#        'Home Team Goals', 'Away Team Goals', 'Away Team Name',
#        'Win conditions', 'Attendance', 'Half-time Home Goals',
#        'Half-time Away Goals', 'Referee', 'Assistant 1', 'Assistant 2',
#        'RoundID', 'MatchID', 'Home Team Initials', 'Away Team Initials',
#        'Total Goals', 'Half-time Goals'],
#       dtype='object')

# %% [markdown]
# ## Summary
#
# In this lab, you practiced accessing data within Pandas!
